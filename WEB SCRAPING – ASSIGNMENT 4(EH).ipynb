# %% [markdown]
# ## WEB SCRAPING–ASSIGNMENT 4 using Exceptions handling(selenium & BeautifulSoup)

# %% [markdown]
# ### links:
# 1. https://selenium-python.readthedocs.io/api.html
# 2. https://www.guru99.com/exception-handling-selenium.html
# 3. https://stackoverflow.com/questions/38022658/selenium-python-handling-no-such-elementexception/
# 38023345

# %%
# Importing Libraries

import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import csv
import time 
from time import sleep
import html5lib
import html.parser
import warnings
warnings.filterwarnings("ignore")

# Importing selenium webdriver 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests
import urllib.request
from urllib.request import urlopen
# importing regex
import re

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#sent get request to page server to source code of the page
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
response = requests.get(url)

# %%
# since the source code we recive is 200 ;Hence it is safe to extract data from this site ,we'll extract data now
soup = BeautifulSoup(response.content, 'html.parser')

# %%
main_table = soup.find('table', class_='wikitable sortable')
main_table
# Out:
# <table class="wikitable sortable">
# <caption>Top 30 most-viewed YouTube videos<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[2]</a></sup>
# </caption>
# <tbody><tr>
# <th><abbr title="Number">No.</abbr>
# </th>
# <th>Video name
# </th>
# <th>Uploader
# </th>
# <th>Views (billions)
# </th>
# <th data-sort-type="usLongDate">Upload date
# </th>
# <th class="unsortable">Note
# </th></tr>
# <tr>
# <td align="center">1.</td>
# <td>"<a class="mw-redirect" href="/wiki/Baby_Shark_Dance" title="Baby Shark Dance">Baby Shark Dance</a>"<sup class="reference" id="cite_ref-Baby_Shark_Dance_4-0"><a href="#cite_note-Baby_Shark_Dance-4">[3]</a></sup></td>
# <td><a href="/wiki/Pinkfong" title="Pinkfong">Pinkfong Baby Shark - Kids' Songs &amp; Stories</a></td>
# <td align="center">10.21</td>
# <td align="right">June 17, 2016</td>
# <td align="center"><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[B]</a></sup>
# </td></tr>
# <tr>
# <td align="center">2.</td>
# ...

# %%
type(main_table)
# Out:
# bs4.element.Tag

# %%
# we have to obtain and display header tag's
header_tags = ["h1", "h2", "h3", "h4", "h5", "h6"]
for tags in soup.find_all(header_tags):
    print(tags.name + ' = ' + tags.text.strip())
# Out:
# h1 = List of most-viewed YouTube videos
# h2 = Contents
# h2 = Top videos
# h2 = Billion View Club
# h2 = Historical most-viewed videos
# h2 = Other milestones
# h2 = See also
# h2 = Notes
# h2 = References
# h2 = Navigation menu
# h3 = Personal tools
# h3 = Namespaces
# h3 = English
# expanded
# collapsed
# h3 = Views
# h3 = More
# expanded
# collapsed
# h3 = Search
# h3 = Navigation
# h3 = Contribute
# h3 = Tools
# h3 = Print/export
# h3 = Languages

# %%
main_data = []
for row in main_table.find_all('tr'):
    col = row.find_all("td")
    col = [ele.text.strip().replace("\n"," ") for ele in col]
    main_data.append(col)  

ytube_video_df = pd.DataFrame(main_data)
ytube_video_df.columns = ["Rank","Video Name", "Uploader (Artist)", "Views (billions)", "Upload Date","-"]
ytube_video_df.iloc[1:31,1:5]
# Out:
#                                          Video Name  \
# 1                             "Baby Shark Dance"[3]
# 2                                    "Despacito"[6]
# 3                        "Johny Johny Yes Papa"[12]
# 4                                "Shape of You"[13]
# 5                               "See You Again"[15]
# 6                                   "Bath Song"[20]
# 7   "Learning Colors – Colorful Eggs on a Farm"[21]
# 8    "Masha and the Bear – Recipe for Disaster"[22]
# 9                 "Phonics Song with Two Words"[23]
# 10                                "Uptown Funk"[24]
# 11                              "Gangnam Style"[25]
# 12                             "Dame Tu Cosita"[30]
# 13                          "Wheels on the Bus"[31]
# 14                                      "Sugar"[32]
# 15                                       "Roar"[33]
# 16                                      "Sorry"[34]
# 17                             "Counting Stars"[35]
# ...

# %%
# Save DataFrame as csv file:
ytube_video_df.to_csv('ytube_video_df.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Require Libraries install:

# %%
conda install -c conda-forge python-chromedriver-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dell\anaconda3
#
#   added / updated specs:
#     - python-chromedriver-binary
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-chromedriver-binary-99.0.4844.35.0|   py38haa244fe_0         5.6 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   python-chromedriv~ conda-forge/win-64::python-chromedriver-binary-99.0.4844.35.0-py38haa244fe_0
#
#
#
# ...
#
# python-chromedriver- | 5.6 MB    |            |   0%
# python-chromedriver- | 5.6 MB    |            |   0%
# python-chromedriver- | 5.6 MB    | 3          |   3%
# ...

# %%
conda install -c conda-forge webdrivermanager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dell\anaconda3
#
#   added / updated specs:
#     - webdrivermanager
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     webdrivermanager-0.10.0    |     pyhd8ed1ab_0          17 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          17 KB
#
# The following NEW packages will be INSTALLED:
#
#   webdrivermanager   conda-forge/noarch::webdrivermanager-0.10.0-pyhd8ed1ab_0
#
#
#
# ...
#
# webdrivermanager-0.1 | 17 KB     |            |   0%
# webdrivermanager-0.1 | 17 KB     | #########4 |  94%
# webdrivermanager-0.1 | 17 KB     | ########## | 100%
# Preparing transaction: ...working... done
# ...

# %%
pip install webdriver-manager
# Out:
# ...
#
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# There is no [win32] chromedriver for browser  in cache
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")
# As we have already installed the important libraries hence we need not to install them further.
url = "https://www.bcci.tv/"
driver.get(url)
driver.maximize_window()
icc_inter = driver.find_element_by_xpath("/html/body/div[14]/div/div[1]/div[2]/ul[1]/li[2]/a").click()
icc_inter = driver.find_element_by_xpath("/html/body/div[14]/div/div[1]/div[2]/ul[1]/li[2]/a").click()
#Scraping Details:

Series = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div[1]").text

Match = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[2]/div/div[2]/div/div[1]").text

Place = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[1]").text

Date = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div[1]/div[2]/div/div[1]/div/div[1]/h5").text

Time = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div[1]/div[2]/div/div[1]/div/div[2]/h5").text


list_name1 =str.splitlines(Series)
df1 = pd.DataFrame(list_name1, columns=["Series"])

list_name2 =str.splitlines(Match)
df2 = pd.DataFrame(list_name2, columns=["Match"])

list_name3 =str.splitlines(Place)
df3 = pd.DataFrame(list_name3, columns=["Place"])

list_name4 =str.splitlines(Date)
df4 = pd.DataFrame(list_name4, columns=["Date"])

list_name5 =str.splitlines(Time)
df5 = pd.DataFrame(list_name5, columns=["Time"])
df6 = df1.join(df2).join(df3).join(df4).join(df5)
international = df6
international.head(1)

# %%
import selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.action_chains import ActionChains

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")
url = "https://www.bcci.tv/"
driver.get(url)
driver.maximize_window()

# %%
inter_mat = driver.find_element_by_xpath('//button[@class="match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3"]').click()

# %%
# Empty List:

match_title=[]
series_name=[]
place=[]
match_time=[]
match_date=[]

# %%
#Scraping data details:

try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding"]'):
        match_title.append(i.text)
except NoSuchElementException:
    match_title.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="fix-place ng-binding ng-scope"]'):
        series_name.append(i.text.split(' - ')[0])
except NoSuchElementException:
    series_name.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]'):
        place.append(i.text)
except NoSuchElementException:        
    place.append('-')
    
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule "]/h5'):
        match_time.append(i.text)
except NoSuchElementException:
    match_time.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="match-card-left match-schedule"]/h5'):
        match_date.append(i.text)
except NoSuchElementException:        
    match_date.append('-')

# %%
# Deriving the Data in to dataset

# %%
bcci_data= pd.DataFrame({'Title of match':match_title,'Series Name':series_name,'Match Place':place,'Date Of Match':match_date,'Time Of Match':match_time})
bcci_data
# Out:
#                                 Title of match                Series Name  \
# 0      SRI LANKA TOUR OF INDIA T20 SERIES 2022                   3rd T20I
# 1     SRI LANKA TOUR OF INDIA TEST SERIES 2022                   1st Test
# 2                    ICC WOMENS WORLD CUP 2022  Bay Oval, Mount Maunganui
# 3                    ICC WOMENS WORLD CUP 2022      Seddon Park, Hamilton
# 4     SRI LANKA TOUR OF INDIA TEST SERIES 2022                   2nd Test
# 5                    ICC WOMENS WORLD CUP 2022      Seddon Park, Hamilton
# 6                    ICC WOMENS WORLD CUP 2022  Bay Oval, Mount Maunganui
# 7                    ICC WOMENS WORLD CUP 2022        Eden Park, Auckland
# 8                    ICC WOMENS WORLD CUP 2022      Seddon Park, Hamilton
# 9                    ICC WOMENS WORLD CUP 2022  Hagley Oval, Christchurch
# 10  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022                   1st T20I
# 11  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022                   2nd T20I
# ...

# %%
# Save DataFrame as csv file:
bcci_data.to_csv('bcci_data.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url = 'https://www.guru99.com/exception-handling-selenium.html'
driver.get(url)
driver.maximize_window()
#Creating Empty list
Name=[]
Description=[]

# %%
# Scraping data:

Name = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]'):
    Name.append(i.text)
    
Description = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]'):
    Description.append(i.text)

# %%
data= pd.DataFrame({'Name Of Exception':Name,'Description':Description})
data
# Out:
#                       Name Of Exception  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
# Save DataFrame as csv file:
data.to_csv('exception.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP at current price (19-20)
#
# D) GSDP at current price (18-19)
#
# E) Share(18-19)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")
url='http://statisticstimes.com/'
driver.get(url)
driver.maximize_window()

# %%
# Search for State-wise GDP:

search_content_economy = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

Search_ind = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').click()

gdp=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %% [markdown]
# ### Get the new url after applying some filter:

# %%
url_new = "https://statisticstimes.com/economy/india/indian-states-gdp.php"
response = requests.get(url_new)

response.status_code
soup = BeautifulSoup(response.content, 'html.parser')

# %%
main_table = soup.find('table', class_='display dataTable')

# %%
main_data=[]

main_table = soup.find('table', id='table_id')

for row in main_table.find_all('tr'):
    col = row.find_all("td")
    col = [ele.text.strip().replace("\n"," ") for ele in col]
    main_data.append(col)  

pd.set_option("display.max_rows",None)
gdp_df = pd.DataFrame(main_data)
gdp_df.columns = ["Rank", "State","GSDP at current price (19-20)","GSDP at current price (18-19)","Share(18-19)","GDP($ billion)","GSDP (Cr INR at 2011-12 prices) [19 - 20]","GSDP (Cr INR at 2011-12 prices) [18 -19]"]
gdp_df.drop(gdp_df.index[[0,1,35]], inplace=True)
gdp_df.reset_index(drop=True, inplace=True)
gdp_df
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# ...

# %%
# Save DataFrame as csv file:
gdp_df.to_csv('gdp.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url = "https://github.com/"
driver.get(url)
driver.maximize_window()

# %%
Options_btn = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary').click()


# selecting trending 
trending = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a').click()

# %%
# creating empty list
repo_urls=[]
title = []
desp = []
count = []
lang = []
language=[]

# %%
#Fetching urls for each repository

repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    repo_urls.append(i.get_attribute("href"))


#Scraping title
ti = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in ti:
    title.append(i.text)

    
#Scraping data from every repository page
for i in repo_urls:
    driver.get(i)
    time.sleep(5)
    
    
    #decription
    try:
        desc = driver.find_element_by_xpath('//p[@class="f4 my-3"]')
        desp.append(desc.text)
    except NoSuchElementException:
        desp.append('-')
        
        
    #contributors
    try:
        cont_tags = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        count.append(cont_tags.text.replace('Contributors',''))
    except NoSuchElementException:
        count.append('-')
        
        
    #Languages 
    try:
        for i in driver.find_elements_by_xpath('//a[@class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3"]'):
            lang.append(i.text.replace('\n',''))
        language.append(lang)
    except NoSuchElementException:
        language.append('-')

# %%
detail = {'Title':title,'Description':desp,'Contributor Counts':count,'Languages Used':language}

# %%
# Creating the DataFrame - 
trending_Repo= pd.DataFrame({'Title':title,'Description':desp,'Contributor Counts':count,'Languages Used':language})
trending_Repo

# %%
# Dataset:

final_tr_repo = pd.DataFrame(detail)
final_tr_repo
# Out:
#                                                Title  \
# 0                             AppFlowy-IO / AppFlowy
# 1   cat-milk / Anime-Girls-Holding-Programming-Books
# 2                        dj-nitehawk / FastEndpoints
# 3                                   Azure / AlwaysOn
# 4               krol3 / container-security-checklist
# 5                                 planetscale / beam
# 6                           louisyoungx / JD-SHOPPER
# 7                              nusr / hacker-laws-zh
# 8                                 phil-opp / blog_os
# 9                     labuladong / fucking-algorithm
# 10                                   sampotts / plyr
# 11                           rust-lang / rust-clippy
# 12            GrowingGit / GitHub-Chinese-Top-Charts
# 13              KumarRobotics / kr_autonomous_flight
# 14          trimstray / the-book-of-secret-knowledge
# 15                                      YaoApp / yao
# 16                                 MHProDev / MHDDoS
# ...

# %%
final_tr_repo.to_csv('uci.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")
url = "https://www.billboard.com/"
driver.get(url)
driver.maximize_window()

# %%
#object of ActionChains
a = ActionChains(driver)
#identify element
m = driver.find_element_by_link_text("CHARTS")
#hover over element
a.move_to_element(m).perform()
#identify sub menu element
n = driver.find_element_by_link_text("Hot 100")
# hover over element and click
a.move_to_element(n).click().perform()
print("Page title: " + driver.title)
# Out:
# Page title: The Hot 100 – Billboard

# %%
new_url = driver.current_url
new_url
# Out:
# 'https://www.billboard.com/charts/hot-100/'

# %%
new_url = "https://www.billboard.com/charts/hot-100/"
page = requests.get(new_url)


soup = BeautifulSoup(page.content)

# %%
name= soup.find_all('li', class_="o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light  lrv-u-padding-l-1@mobile-max")

name1=soup.find_all('li', class_="o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-padding-l-050 lrv-u-padding-l-1@mobile-max")
names=name+name1

# %%
Name = []
for i in names:
    Name.append(i.text.split("\n\n\n")[0].replace("\n\n",""))
    
name= soup.find_all('ul', class_="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max")
Name = []
for i in name:
    Name.append(i.text.split("\n\n\n")[1])
    
artist= soup.find_all('ul', class_="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max")

#extracting top ranking

Artist = []
for i in artist:
    Artist.append(i.text.split("\n\n\n")[2])

lwr= soup.find_all('li', class_="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max")

LWR = []
for i in lwr:
    LWR.append(i.text.replace('\n\n',''))
    
    
woc= soup.find_all('li', class_="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max")

WOC = []
for i in woc:
    WOC.append(i.text.replace('\n\n',''))
    
del WOC[0:201:2]

pr= soup.find_all('li', class_="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max")

PR = []
for i in pr:
    PR.append(i.text.replace('\n\n',''))
    
del PR[0:201:2]

# %%
del LWR[0:201:2]

# %%
# Dataframe:

Top_billboard= pd.DataFrame({'Song Name':Name,'Song Artist':Artist,'Last week rank':LWR,'Peak Rank':PR,'Week on chart':WOC})
Top_billboard
# Out:
#                           Song Name  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                        Easy On Me
# 3                           abcdefu
# 4                              Stay
# 5                     Super Gremlin
# 6                           Shivers
# 7                             Ghost
# 8                 Thats What I Want
# 9                          Pushin P
# 10                 Surface Pressure
# 11          Cold Heart (PNAU Remix)
# 12                     Need To Know
# 13                       Bad Habits
# 14                           MAMIII
# 15                       Levitating
# 16                    Industry Baby
# 17                  Save Your Tears
# 18                      Hrs And Hrs
# 19                           Bussin
# 20          The Joker And The Queen
# 21                    One Right Now
# 22                     Still D.R.E.
# 23              The Family Madrigal
# 24                       Big Energy
# ...

# %%
Top_billboard.to_csv('Billboard.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url = "https://www.naukri.com/"
driver.get(url)
driver.maximize_window()

# %%
search_job=driver.find_element_by_class_name('suggestor-input')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ac77e463e43185ec4283825d5fc8d042", element="38b6dc04-70e4-4d0d-a16b-fe7a5de32f38")>

# %%
#search job:
search_job.send_keys('Data Science')

# %%
search_bar=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search_bar.click()

# %%
recruiter_name=[]
designation=[]
company=[]
skills=[]
location=[]

rec_name = driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
for rec in rec_name:
    recruiter_name.append(rec.text)
    
desig_name = driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for desig in desig_name:
    designation.append(desig.text)    
    
comp_name = driver.find_elements_by_xpath("//a[@class='ellipsis']")
for com in comp_name:
    company.append(com.text)     
    comp_tit = company[1:101:2]
    
skill_name = driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for skill in skill_name:
    skills.append(skill.text)    

loc_name = driver.find_elements_by_xpath("//p[@class='highlightable']")
for loc in loc_name:
    location.append(loc.text)

# %%
new_loc =pd.DataFrame(location, columns =["a"])
new_loc = new_loc["a"].str.split("\n", expand=True)
new_loc.drop(columns=[0,1,2], inplace=True)    
new_loc.columns = ["Location"]

# %%
all_recruiter = {
                "Recruiter Name":recruiter_name,
                "Designation":designation,
                "Company":company,
                "Skills they hire for":skills,
                "Location":location
            }

# %%
# Dataset: 
df_rec = pd.DataFrame(all_recruiter)

# %%
df_rec.to_csv('df_rec.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url=' https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
# creating empty list:
name=[]
author = []
volumes = []
publisher = []
genre = []


#Scraping data of Book details:

try:
    for i in driver.find_elements_by_xpath('//td[@class="left"][2]'):
        name.append(i.text)
except NoSuchElementException:
    name.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//td[@class="left"][3]'):
        author.append(i.text)
except NoSuchElementException:
    author.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//td[@class="left"][4]'):
        volumes.append(i.text)
except NoSuchElementException:        
    volumes.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//td[@class="left"][5]'):
        publisher.append(i.text)
except NoSuchElementException:        
    publisher.append('-')
    

try:
    for i in driver.find_elements_by_xpath('//td[@class="last left"]'):
        genre.append(i.text)
except NoSuchElementException:
    genre.append('-')

# %%
# DataFrame:
Book_detail= pd.DataFrame({'Book Name':name,'Author Name':author,'Volume Sold':volumes,'Publisher':publisher,'Genre':genre})
Book_detail
# Out:
#                                             Book Name  \
# 0                                   Da Vinci Code,The
# 1                Harry Potter and the Deathly Hallows
# 2            Harry Potter and the Philosopher's Stone
# 3           Harry Potter and the Order of the Phoenix
# 4                                Fifty Shades of Grey
# 5                 Harry Potter and the Goblet of Fire
# 6             Harry Potter and the Chamber of Secrets
# 7            Harry Potter and the Prisoner of Azkaban
# 8                                   Angels and Demons
# 9   Harry Potter and the Half-blood Prince:Childre...
# 10                                Fifty Shades Darker
# 11                                           Twilight
# 12  Girl with the Dragon Tattoo,The:Millennium Tri...
# 13                                 Fifty Shades Freed
# 14                                    Lost Symbol,The
# 15                                           New Moon
# ...

# %%
Book_detail.to_csv('Book_detail.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url=' https://www.imdb.com/list/ls095964455/'
driver.get(url)
driver.maximize_window()

# %%
# creating empty list
name=[]
year_span = []
genre = []
runtime = []
rating = []
votes=[]

# %%
#Scraping data of details


try:
    for i in driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a '):
        name.append(i.text)
except NoSuchElementException:
    name.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"] '):
        year_span.append(i.text)
except NoSuchElementException:
    year_span.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="genre"]'):
        genre.append(i.text)
except NoSuchElementException:        
    genre.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="runtime"] '):
        runtime.append(i.text)
except NoSuchElementException:        
    runtime.append('-')
    
try:
    for i in driver.find_elements_by_xpath('//p[@class="text-muted text-small"][3] '):
        votes.append(i.text.split(":")[1])
except NoSuchElementException:
    votes.append('-')

    
try:
    for i in driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]'):
        rating.append(i.text)
except NoSuchElementException:
    rating.append('-')

# %%
# DataFrame - 
watched_tv_show= pd.DataFrame({'Show Name':name,'Year span':year_span,'Genre':genre,'Run time':runtime,'Ratings':rating,'Votes':votes})
watched_tv_show
# Out:
#                          Show Name    Year span                         Genre  \
# 0                  Game of Thrones  (2011–2019)      Action, Adventure, Drama
# 1                  Stranger Things     (2016– )        Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)       Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)      Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)        Drama, Mystery, Sci-Fi
# 5          Orange Is the New Black  (2013–2019)          Comedy, Crime, Drama
# 6                        Riverdale     (2017– )         Crime, Drama, Mystery
# 7                   Grey's Anatomy     (2005– )                Drama, Romance
# 8                        The Flash     (2014– )      Action, Adventure, Drama
# 9                            Arrow  (2012–2020)      Action, Adventure, Crime
# 10                     Money Heist  (2017–2021)          Action, Crime, Drama
# ...

# %%
watched_tv_show.to_csv('watched_tv_show.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome(r"C:\driver\chromedriver.exe")

url='https://archive.ics.uci.edu/'
driver.get(url)
driver.maximize_window()

# %%
explore_datasets = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td/span/b/a").click()

# %%
viewall=driver.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b').click()

# %%
new_url = driver.current_url
new_url
# Out:
# 'https://archive.ics.uci.edu/ml/datasets.php'

# %%
pd.set_option("display.max_rows",None)
table_MN = pd.read_html(new_url, header =0)

# %%
new_datasets = table_MN[5]
new_datasets
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# 5                                Artificial Characters
# 6                                 Audiology (Original)
# 7                             Audiology (Standardized)
# 8                                             Auto MPG
# 9                                           Automobile
# 10                                              Badges
# 11                                       Balance Scale
# 12                                            Balloons
# 13                                       Breast Cancer
# 14                  Breast Cancer Wisconsin (Original)
# 15                Breast Cancer Wisconsin (Prognostic)
# ...

# %%
new_datasets.to_csv('uci.csv', index=False, encoding='utf-8')
